# %%
from functools import partial

@partial(lambda gen: lambda n: list(gen(n)))
def fib(n):
    a, b = 0, 1
    for _ in range(n):
        yield a
        a, b = b, a + b
        
fib(8)
# Out:
# [0, 1, 1, 2, 3, 5, 8, 13]
